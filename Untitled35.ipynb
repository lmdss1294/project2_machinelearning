# %% [markdown]
# <a href="https://colab.research.google.com/github/lmdss1294/project2_machinelearning/blob/main/Untitled35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 데이터 파일 경로와 파일 이름을 리스트에 저장
train_files = ['https://raw.githubusercontent.com/lmdss1294/project2_machinelearning/main/data/2010.csv',
               'https://raw.githubusercontent.com/lmdss1294/project2_machinelearning/main/data/2011.csv',
               'https://raw.githubusercontent.com/lmdss1294/project2_machinelearning/main/data/2012.csv',
               'https://raw.githubusercontent.com/lmdss1294/project2_machinelearning/main/data/2013.csv']


# 데이터프레임 리스트 생성
dfs = []
for file in train_files:
    dfs.append(pd.read_csv(file))

# 데이터프레임 병합
train_data = pd.concat(dfs, ignore_index=True)

# 결과 확인
print(train_data.head())
# Out:
#     항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0  제주항공   7C508    CJU    PUS  지연    220.0   1.000     1.000  10000.0
# 1  대한항공  KE1806    CJU    TAE  출발    277.5   5.750     5.750  10000.0
# 2  에어부산  BX8112    CJU    PUS  출발    275.0   5.833     5.833  10000.0
# 3  대한항공  KE1244    CJU    GMP  출발    275.0   5.833     5.833  10000.0
# 4  제주항공   7C506    CJU    PUS  출발    272.5   5.917     5.917  10000.0
#
#    1층 운량(1/8)  1층 운형(null)  1층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# 0       1.000          6.0   3000.000   3.100     -5.300   1020.300
# 1       0.250          0.0   5000.000   5.650     -4.075   1020.300
# 2       0.167          0.0   3333.333   5.633     -4.083   1020.333
# 3       0.167          0.0   3333.333   5.633     -4.083   1020.333
# 4       0.083          0.0   1666.667   5.617     -4.092   1020.367
#
#    현지기압(hPa)  강수량(mm)
# 0   1017.100      0.0
# 1   1017.125      0.0
# 2   1017.150      0.0
# 3   1017.150      0.0
# 4   1017.175      0.0

# %%
train_data
# Out:
#           항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0        제주항공   7C508    CJU    PUS  지연  220.000   1.000     1.000  10000.0
# 1        대한항공  KE1806    CJU    TAE  출발  277.500   5.750     5.750  10000.0
# 2        에어부산  BX8112    CJU    PUS  출발  275.000   5.833     5.833  10000.0
# 3        대한항공  KE1244    CJU    GMP  출발  275.000   5.833     5.833  10000.0
# 4        제주항공   7C506    CJU    PUS  출발  272.500   5.917     5.917  10000.0
# ...       ...     ...    ...    ...  ..      ...     ...       ...      ...
# 53064    대한항공  KE1226    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53065     진에어   LJ310    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53066    대한항공  KE1852    CJU    WJU  지연  311.667  18.500    19.667   5600.0
# 53067  아시아나항공  OZ8924    CJU    GMP  지연  313.333  19.000    21.333   5200.0
# 53068    대한항공   KE755    CJU    NGO  지연  320.000  22.000    29.000   6000.0
#
#        1층 운량(1/8)  1층 운형(null)  1층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# 0           1.000        6.000   3000.000   3.100     -5.300   1020.300
# 1           0.250        0.000   5000.000   5.650     -4.075   1020.300
# 2           0.167        0.000   3333.333   5.633     -4.083   1020.333
# 3           0.167        0.000   3333.333   5.633     -4.083   1020.333
# 4           0.083        0.000   1666.667   5.617     -4.092   1020.367
# ...           ...          ...        ...     ...        ...        ...
# 53064       7.000        8.000   2500.000   0.800     -1.700   1015.200
# 53065       7.000        8.000   2500.000   0.800     -1.700   1015.200
# 53066       6.583        8.083   2416.667   0.717     -1.625   1015.217
# 53067       6.167        8.167   2333.333   0.633     -1.550   1015.233
# 53068       7.000        8.000   2500.000   0.500     -1.500   1015.450
#
#        현지기압(hPa)  강수량(mm)
# 0       1017.100     0.00
# 1       1017.125     0.00
# 2       1017.150     0.00
# 3       1017.150     0.00
# 4       1017.175     0.00
# ...          ...      ...
# 53064   1012.000     0.00
# 53065   1012.000     0.00
# 53066   1012.017     0.05
# 53067   1012.033     0.10
# 53068   1012.250     0.00
#
# [53069 rows x 17 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53069 entries, 0 to 53068
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   항공사          52960 non-null  object
#  1   편명           53069 non-null  object
#  2   출발공항코드       53069 non-null  object
#  3   도착공항코드       53069 non-null  object
#  4   현황           53069 non-null  object
#  5   풍향(deg)      53069 non-null  float64
#  6   풍속(KT)       53069 non-null  float64
#  7   순간풍속(KT)     53069 non-null  float64
#  8   시정(m)        53069 non-null  float64
#  9   1층 운량(1/8)   53069 non-null  float64
#  10  1층 운형(null)  53069 non-null  float64
#  11  1층 운고(FT)    53069 non-null  float64
#  12  기온(°C)       53069 non-null  float64
#  13  이슬점온도(°C)    53069 non-null  float64
#  14  해면기압(hPa)    53069 non-null  float64
#  15  현지기압(hPa)    53069 non-null  float64
#  16  강수량(mm)      53069 non-null  float64
# dtypes: float64(12), object(5)
# memory usage: 6.9+ MB

# %%
train_data['항공사'].fillna('개인',inplace = True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53069 entries, 0 to 53068
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   항공사          53069 non-null  object
#  1   편명           53069 non-null  object
#  2   출발공항코드       53069 non-null  object
#  3   도착공항코드       53069 non-null  object
#  4   현황           53069 non-null  object
#  5   풍향(deg)      53069 non-null  float64
#  6   풍속(KT)       53069 non-null  float64
#  7   순간풍속(KT)     53069 non-null  float64
#  8   시정(m)        53069 non-null  float64
#  9   1층 운량(1/8)   53069 non-null  float64
#  10  1층 운형(null)  53069 non-null  float64
#  11  1층 운고(FT)    53069 non-null  float64
#  12  기온(°C)       53069 non-null  float64
#  13  이슬점온도(°C)    53069 non-null  float64
#  14  해면기압(hPa)    53069 non-null  float64
#  15  현지기압(hPa)    53069 non-null  float64
#  16  강수량(mm)      53069 non-null  float64
# dtypes: float64(12), object(5)
# memory usage: 6.9+ MB

# %%
train_data.drop(labels = ['1층 운량(1/8)','1층 운형(null)','1층 운고(FT)'],axis = 1, inplace = True)

# %%
train_data
# Out:
#           항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0        제주항공   7C508    CJU    PUS  지연  220.000   1.000     1.000  10000.0
# 1        대한항공  KE1806    CJU    TAE  출발  277.500   5.750     5.750  10000.0
# 2        에어부산  BX8112    CJU    PUS  출발  275.000   5.833     5.833  10000.0
# 3        대한항공  KE1244    CJU    GMP  출발  275.000   5.833     5.833  10000.0
# 4        제주항공   7C506    CJU    PUS  출발  272.500   5.917     5.917  10000.0
# ...       ...     ...    ...    ...  ..      ...     ...       ...      ...
# 53064    대한항공  KE1226    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53065     진에어   LJ310    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53066    대한항공  KE1852    CJU    WJU  지연  311.667  18.500    19.667   5600.0
# 53067  아시아나항공  OZ8924    CJU    GMP  지연  313.333  19.000    21.333   5200.0
# 53068    대한항공   KE755    CJU    NGO  지연  320.000  22.000    29.000   6000.0
#
#        기온(°C)  이슬점온도(°C)  해면기압(hPa)  현지기압(hPa)  강수량(mm)
# 0       3.100     -5.300   1020.300   1017.100     0.00
# 1       5.650     -4.075   1020.300   1017.125     0.00
# 2       5.633     -4.083   1020.333   1017.150     0.00
# 3       5.633     -4.083   1020.333   1017.150     0.00
# 4       5.617     -4.092   1020.367   1017.175     0.00
# ...       ...        ...        ...        ...      ...
# 53064   0.800     -1.700   1015.200   1012.000     0.00
# 53065   0.800     -1.700   1015.200   1012.000     0.00
# 53066   0.717     -1.625   1015.217   1012.017     0.05
# 53067   0.633     -1.550   1015.233   1012.033     0.10
# 53068   0.500     -1.500   1015.450   1012.250     0.00
#
# [53069 rows x 14 columns]

# %%
train_data.drop(labels = '편명',axis = 1,inplace = True)

# %%
test_files = ['https://raw.githubusercontent.com/lmdss1294/project2_machinelearning/main/data/2014.csv']

# 데이터프레임 리스트 생성
dfs = []
for file in train_files:
    dfs.append(pd.read_csv(file))

# 데이터프레임 병합
test_data = pd.concat(dfs, ignore_index=True)

# 결과 확인
print(test_data.head())
# Out:
#     항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0  제주항공   7C508    CJU    PUS  지연    220.0   1.000     1.000  10000.0
# 1  대한항공  KE1806    CJU    TAE  출발    277.5   5.750     5.750  10000.0
# 2  에어부산  BX8112    CJU    PUS  출발    275.0   5.833     5.833  10000.0
# 3  대한항공  KE1244    CJU    GMP  출발    275.0   5.833     5.833  10000.0
# 4  제주항공   7C506    CJU    PUS  출발    272.5   5.917     5.917  10000.0
#
#    1층 운량(1/8)  1층 운형(null)  1층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# 0       1.000          6.0   3000.000   3.100     -5.300   1020.300
# 1       0.250          0.0   5000.000   5.650     -4.075   1020.300
# 2       0.167          0.0   3333.333   5.633     -4.083   1020.333
# 3       0.167          0.0   3333.333   5.633     -4.083   1020.333
# 4       0.083          0.0   1666.667   5.617     -4.092   1020.367
#
#    현지기압(hPa)  강수량(mm)
# 0   1017.100      0.0
# 1   1017.125      0.0
# 2   1017.150      0.0
# 3   1017.150      0.0
# 4   1017.175      0.0

# %%
test_data['항공사'].fillna('개인',inplace = True)

# %%
test_data.drop(labels = ['1층 운량(1/8)','1층 운형(null)','1층 운고(FT)'],axis = 1, inplace = True)

# %%
test_data
# Out:
#           항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0        제주항공   7C508    CJU    PUS  지연  220.000   1.000     1.000  10000.0
# 1        대한항공  KE1806    CJU    TAE  출발  277.500   5.750     5.750  10000.0
# 2        에어부산  BX8112    CJU    PUS  출발  275.000   5.833     5.833  10000.0
# 3        대한항공  KE1244    CJU    GMP  출발  275.000   5.833     5.833  10000.0
# 4        제주항공   7C506    CJU    PUS  출발  272.500   5.917     5.917  10000.0
# ...       ...     ...    ...    ...  ..      ...     ...       ...      ...
# 53064    대한항공  KE1226    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53065     진에어   LJ310    CJU    GMP  지연  310.000  18.000    18.000   6000.0
# 53066    대한항공  KE1852    CJU    WJU  지연  311.667  18.500    19.667   5600.0
# 53067  아시아나항공  OZ8924    CJU    GMP  지연  313.333  19.000    21.333   5200.0
# 53068    대한항공   KE755    CJU    NGO  지연  320.000  22.000    29.000   6000.0
#
#        기온(°C)  이슬점온도(°C)  해면기압(hPa)  현지기압(hPa)  강수량(mm)
# 0       3.100     -5.300   1020.300   1017.100     0.00
# 1       5.650     -4.075   1020.300   1017.125     0.00
# 2       5.633     -4.083   1020.333   1017.150     0.00
# 3       5.633     -4.083   1020.333   1017.150     0.00
# 4       5.617     -4.092   1020.367   1017.175     0.00
# ...       ...        ...        ...        ...      ...
# 53064   0.800     -1.700   1015.200   1012.000     0.00
# 53065   0.800     -1.700   1015.200   1012.000     0.00
# 53066   0.717     -1.625   1015.217   1012.017     0.05
# 53067   0.633     -1.550   1015.233   1012.033     0.10
# 53068   0.500     -1.500   1015.450   1012.250     0.00
#
# [53069 rows x 14 columns]

# %%
test_data.drop(labels = '편명',axis = 1, inplace = True)

# %%
test_data.describe()
# Out:
#             풍향(deg)        풍속(KT)      순간풍속(KT)         시정(m)        기온(°C)  \
# count  53069.000000  53069.000000  53069.000000  53069.000000  53069.000000
# mean     185.276388      8.531267      8.964512   7999.101045     16.455075
# std      112.852881      5.458949      6.653124   2304.909828      8.238788
# min        0.000000      0.000000      0.000000  -1291.667000     -1.500000
# 25%       75.833000      4.333000      4.333000   6000.000000      9.725000
# 50%      190.000000      7.167000      7.167000   8166.667000     16.567000
# 75%      298.333000     12.000000     12.000000  10000.000000     22.800000
# max      376.667000     33.000000     53.000000  10000.000000     33.500000
#
#           이슬점온도(°C)     해면기압(hPa)     현지기압(hPa)       강수량(mm)
# count  53069.000000  53069.000000  53069.000000  53069.000000
# mean      10.501099   1016.206904   1013.190082      0.151724
# std        9.729523      7.125486      7.017326      0.951384
# min      -10.675000    991.450000    988.600000      0.000000
# 25%        1.875000   1011.550000   1008.617000      0.000000
# 50%       11.000000   1015.900000   1012.867000      0.000000
# 75%       19.200000   1021.833000   1018.700000      0.000000
# max       26.933000   1035.000000   1031.800000     37.600000

# %%
target = '현황'

# %%
test_data.describe()
# Out:
#             풍향(deg)        풍속(KT)      순간풍속(KT)         시정(m)        기온(°C)  \
# count  53069.000000  53069.000000  53069.000000  53069.000000  53069.000000
# mean     185.276388      8.531267      8.964512   7999.101045     16.455075
# std      112.852881      5.458949      6.653124   2304.909828      8.238788
# min        0.000000      0.000000      0.000000  -1291.667000     -1.500000
# 25%       75.833000      4.333000      4.333000   6000.000000      9.725000
# 50%      190.000000      7.167000      7.167000   8166.667000     16.567000
# 75%      298.333000     12.000000     12.000000  10000.000000     22.800000
# max      376.667000     33.000000     53.000000  10000.000000     33.500000
#
#           이슬점온도(°C)     해면기압(hPa)     현지기압(hPa)       강수량(mm)
# count  53069.000000  53069.000000  53069.000000  53069.000000
# mean      10.501099   1016.206904   1013.190082      0.151724
# std        9.729523      7.125486      7.017326      0.951384
# min      -10.675000    991.450000    988.600000      0.000000
# 25%        1.875000   1011.550000   1008.617000      0.000000
# 50%       11.000000   1015.900000   1012.867000      0.000000
# 75%       19.200000   1021.833000   1018.700000      0.000000
# max       26.933000   1035.000000   1031.800000     37.600000

# %%
test_data['시정(m)'] = test_data['시정(m)'].abs()
train_data['시정(m)'] = train_data['시정(m)'].abs()

# %%
test_data.describe()
# Out:
#             풍향(deg)        풍속(KT)      순간풍속(KT)         시정(m)        기온(°C)  \
# count  53069.000000  53069.000000  53069.000000  53069.000000  53069.000000
# mean     185.276388      8.531267      8.964512   7999.193691     16.455075
# std      112.852881      5.458949      6.653124   2304.588271      8.238788
# min        0.000000      0.000000      0.000000     50.000000     -1.500000
# 25%       75.833000      4.333000      4.333000   6000.000000      9.725000
# 50%      190.000000      7.167000      7.167000   8166.667000     16.567000
# 75%      298.333000     12.000000     12.000000  10000.000000     22.800000
# max      376.667000     33.000000     53.000000  10000.000000     33.500000
#
#           이슬점온도(°C)     해면기압(hPa)     현지기압(hPa)       강수량(mm)
# count  53069.000000  53069.000000  53069.000000  53069.000000
# mean      10.501099   1016.206904   1013.190082      0.151724
# std        9.729523      7.125486      7.017326      0.951384
# min      -10.675000    991.450000    988.600000      0.000000
# 25%        1.875000   1011.550000   1008.617000      0.000000
# 50%       11.000000   1015.900000   1012.867000      0.000000
# 75%       19.200000   1021.833000   1018.700000      0.000000
# max       26.933000   1035.000000   1031.800000     37.600000

# %%
train_data.describe()
# Out:
#             풍향(deg)        풍속(KT)      순간풍속(KT)         시정(m)        기온(°C)  \
# count  53069.000000  53069.000000  53069.000000  53069.000000  53069.000000
# mean     185.276388      8.531267      8.964512   7999.193691     16.455075
# std      112.852881      5.458949      6.653124   2304.588271      8.238788
# min        0.000000      0.000000      0.000000     50.000000     -1.500000
# 25%       75.833000      4.333000      4.333000   6000.000000      9.725000
# 50%      190.000000      7.167000      7.167000   8166.667000     16.567000
# 75%      298.333000     12.000000     12.000000  10000.000000     22.800000
# max      376.667000     33.000000     53.000000  10000.000000     33.500000
#
#           이슬점온도(°C)     해면기압(hPa)     현지기압(hPa)       강수량(mm)
# count  53069.000000  53069.000000  53069.000000  53069.000000
# mean      10.501099   1016.206904   1013.190082      0.151724
# std        9.729523      7.125486      7.017326      0.951384
# min      -10.675000    991.450000    988.600000      0.000000
# 25%        1.875000   1011.550000   1008.617000      0.000000
# 50%       11.000000   1015.900000   1012.867000      0.000000
# 75%       19.200000   1021.833000   1018.700000      0.000000
# max       26.933000   1035.000000   1031.800000     37.600000

# %%
train_data.head()
# Out:
#     항공사 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  기온(°C)  \
# 0  제주항공    CJU    PUS  지연    220.0   1.000     1.000  10000.0   3.100
# 1  대한항공    CJU    TAE  출발    277.5   5.750     5.750  10000.0   5.650
# 2  에어부산    CJU    PUS  출발    275.0   5.833     5.833  10000.0   5.633
# 3  대한항공    CJU    GMP  출발    275.0   5.833     5.833  10000.0   5.633
# 4  제주항공    CJU    PUS  출발    272.5   5.917     5.917  10000.0   5.617
#
#    이슬점온도(°C)  해면기압(hPa)  현지기압(hPa)  강수량(mm)
# 0     -5.300   1020.300   1017.100      0.0
# 1     -4.075   1020.300   1017.125      0.0
# 2     -4.083   1020.333   1017.150      0.0
# 3     -4.083   1020.333   1017.150      0.0
# 4     -4.092   1020.367   1017.175      0.0

# %%
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE

# %%
df_train = train_data
df_test = test_data

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# OrdinalEncoder 객체 생성
encoder = OrdinalEncoder()

# 카테고리형 데이터 추출
cat_cols = ['항공사', '출발공항코드', '도착공항코드']
cat_train = df_train[cat_cols]
cat_test = df_test[cat_cols]

# fit_transform() 함수를 이용하여 카테고리형 데이터를 숫자형으로 변환
df_train[cat_cols] = encoder.fit_transform(cat_train)
df_test[cat_cols] = encoder.transform(cat_test)

# %%
df_train['현황'] = df_train['현황'].replace({'지연': '출발', '회항': '취소'})
df_test['현황'] = df_test['현황'].replace({'지연': '출발', '회항': '취소'})

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# SMOTE 적용하여 데이터 증강
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(df_train.drop(columns=['현황']), df_train['현황'])
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
X_test, y_test = df_test.drop(columns=['현황']), df_test['현황']

# %%
y_test
# Out:
# 0        출발
# 1        출발
# 2        출발
# 3        출발
# 4        출발
#          ..
# 53064    출발
# 53065    출발
# 53066    출발
# 53067    출발
# 53068    출발
# Name: 현황, Length: 53069, dtype: object

# %%
set(y_test)
# Out:
# {'출발', '취소'}

# %%
import matplotlib.pyplot as plt

# %%
class_counts = y_test.value_counts()
plt.bar(class_counts.index, class_counts.values)
# Out:
# <BarContainer object of 2 artists>
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52636 (\N{HANGUL SYLLABLE CUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52712 (\N{HANGUL SYLLABLE CWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 그래디언트 부스팅 모델 정의
gb = GradientBoostingClassifier(random_state=42)

# 하이퍼 파라미터 범위 설정
param_dist = {
    'n_estimators': [100, 500, 1000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.1, 1],
    'subsample': [0.5, 0.8, 1],
    'max_features': ['sqrt', 'log2']
}

# 랜덤 서치를 이용한 하이퍼 파라미터 최적화
random_search = RandomizedSearchCV(
    gb,
    param_distributions=param_dist,
    n_iter=50,
    cv=5,
    scoring='f1_macro',
    n_jobs=-1,
    random_state=42
)

random_search.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-bd58f147d2e4> in <cell line: 24>()
#      22 )
#      23
# ---> 24 random_search.fit(X_train, y_train)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1766     def _run_search(self, evaluate_candidates):
#    1767         """Search n_iter candidates from param_distributions"""
# -> 1768         evaluate_candidates(
#    1769             ParameterSampler(
#    1770                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in retrieve(self)
#     936             try:
#     937                 if getattr(self._backend, 'supports_timeout', False):
# --> 938                     self._output.extend(job.get(timeout=self.timeout))
#     939                 else:
#     940                     self._output.extend(job.get())
#
# /usr/local/lib/python3.9/dist-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score

# %%
# 테스트 데이터 예측 및 평가
y_pred = best_model.predict(X_test_selected)
accuracy = accuracy_score(y_test_selected, y_pred)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.6172580026355736

# %%
from sklearn.metrics import f1_score

# 테스트 데이터 예측 및 평가
y_pred = best_model.predict(X_test_selected)
f1 = f1_score(y_test_selected, y_pred, average='macro')
print("Model F1-score:", f1)
# Out:
# Model F1-score: 0.26883414540260836
